# %%
import requests

def ocr_space_file(filename, overlay=False, api_key='9999999', language='eng'):
    payload = {'isOverlayRequired': overlay,
               'apikey': api_key,
               'language': language,
               }
    with open(filename, 'rb') as f:
        r = requests.post('https://api.ocr.space/parse/image',
                          files={'filename': f},
                          data=payload,
                          )
    return r.json()


api_key = '9999'

filename = 'original.jpeg'

result = ocr_space_file(filename, api_key=api_key)

# Process the result
if result['IsErroredOnProcessing']:
    print("Error occurred during processing.")
else:
    parsed_results = result['ParsedResults']
    for parsed_result in parsed_results:
        bankstatement_ocr = parsed_result['ParsedText']
        print("Extracted Text:")
        print(bankstatement_ocr)
# Out:
# Extracted Text:
# Reference
# H13G
# T Hedvig bl
# UNION AKASSA
# Elevio
# Fortun Marke
# KAHLS THE &
# OOPLA
# DIMAS KISTA
# RentDec
# GOOGLE *YouT
# HOME & COOK
# FO Barkarby
# SUBWAY KTH
# 4308164 Pres
# dibz.se
# EATERY KISTA
# LON
# ICA KVANTUM
# ICA KVANTUM
# ICA KVANTUM
# +46765865351
# +46765865351
# PUNJABI GRIL
# ICA KVANTUM
# ICA KVANTUM
# Princh
# NYTIMES
# +46739360117
# +46739360117
# +46739360117
# LaunchGood I
# VY BUSS
# +46739360117
# +46739360117
# TASTE KTH
# COOP KISTA
# W BUSS
# ICA KVANTUM
# ICA KVANTUM
# QOPLA
# CURRYLEAF HB
# ICA KVANTUM
# PUNJABI GRIL
# Liras
# +46739360117
# +46739360117
# MCD 162 - ST
# EATERY KISTA
# +46739360117
# RUSTA - 94 K
# Falafel & Sh
# KVANTUM
# KVANTUM
# ICA KVANTUM
# Booked
# date
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-25
# 2022-11-24
# 2022-11-24
# 2022-11-24
# 2022-11-23
# 2022-11-23
# 2022-11-23
# 2022-11-22
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-18
# 2022-11-17
# 2022-11-16
# 2022-11-15
# 2022-11-15
# 2022-11-14
# 2022-11-14
# 2022-11-14
# 2022-11-14
# 2022-11-14
# 2022-11-14
# 2022-11-14
# 2022-11-11
# 2022-11-11
# 2022-11-11
# 2022-11-09
# 2022-11-09
# 2022-11-08
# 2022-11-07
# 2022-11-07
# Transactio
# date
# 2022-11-26
# 2022-11-26
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-27
# 2022-11-27
# 2022-11-27
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-25
# 2022-11-25
# 2022-11-24
# 2022-11-24
# 2022-11-23
# 2022-11-23
# 2022-11-23
# 2022-11-22
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-20
# 2022-11-20
# 2022-11-20
# 2022-11-20
# 2022-11-19
# 2022-11-19
# 2022-11-19
# 2022-11-19
# 2022-11-18
# 2022-11-17
# 2022-11-15
# 2022-11-15
# 2022-11-15
# 2022-11-14
# 2022-11-13
# 2022-11-13
# 2022-11-12
# 2022-11-12
# 2022-11-12
# 2022-11-12
# 2022-11-11
# 2022-11-11
# 2022-11-11
# 2022-11-09
# 2022-11-09
# 2022-11-08
# 2022-11-06
# 2022-11-06
# Valuo date
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-28
# 2022-11-27
# 2022-11-27
# 2022-11-27
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-26
# 2022-11-25
# 2022-11-25
# 2022-11-24
# 2022-11-24
# 2022-11-23
# 2022-11-24
# 2022-11-24
# 2022-11-22
# 2022-11-21
# 2022-11-21
# 2022-11-21
# 2022-11-20
# 2022-11-20
# 2022-11-21
# 2022-11-21
# 2022-11-19
# 2022-11-19
# 2022-11-19
# 2022-11-21
# 2022-11-18
# 2022-11-17
# 2022-11-15
# 2022-11-15
# 2022-11-15
# 2022-11-14
# 2022-11-13
# 2022-11-13
# 2022-11-12
# 2022-11-12
# 2022-11-14
# 2022-11-14
# 2022-11-11
# 2022-11-11
# 2022-11-14
# 2022-11-09
# 2022-11-09
# 2C22-11-08
# 2022-11-06
# 2022-11-06
# Description
# Balance 2022-11-28
# H13G
# T Hedvig bl
# UNION AKASSA
# Ellevio
# Fortum Marke
# «HLS THE &
# QOPLA
# DIMAS KISTA
# RentDec
# GOOGLE •your
# HOME & COOK
# FO barkarby
# SUBWAY KTH
# 4308164 Pres
# dibz.se
# EATERY KISTA
# LÖN
# ICA KVANTUM
# ICA KVANTUM
# ICA KVANTUM
# Swish paymen
# Swish paymen
# PUNJABI GRIL
# ICA KVANTUM
# ICA KVANTUM
# Swish Princh
# NYTIMES
# Swish paymen
# Swish paymen
# Swish paymen
# LaunchGood I
# Swish w Bus
# Swish paymen
# Swish paymen
# TASTE KTH
# COOP KISTA
# Swish Bus
# ICA KVANTUM
# ICA KVANTUM
# QOPLA
# CURRYLEAF HB
# ICA KVANTUM
# PUNJABI GRIL
# Liras
# Swish paymen
# Swish paymen
# MCD 162 -ST
# EATERY KISTA
# Swish paymen
# RUSTA- 94 K
# Falafel & Sh
# ICA KVANTUM
# ICA KVANTUM
# ICA KVANTUM
# Amount
# SEK
# -745,00
# -149,00
# -140,00
# -656.00
# -915.00
# -82,00
# -220,00
# -114.00
# -10 436.00
# -119,00
# -239.00
# -795,00
# -89.00
# -15,00
# -19,00
# -230,40
# 34 678,80
# -295,00
# -59,80
# -145,20
# 700.00
# 450.00
# -204.00
# -43,80
# -263.50
# -12.00
# -22,41
# -163,00
# 163.00
# 163.00
# -128,77
# -139,00
# 30,00
# -120.00
# -193.30
# -139,00
# -106.06
# -116.88
# -260,00
# -813,00
# -157.60
# -90.00
# -469.00
# 48.00
# 163.00
# -89,00
# -202,30
# 157,00
# -68,80
# -55,00
# -161,43
# -52,90
# -155,03

# %%
import requests

def ocr_space_file(filename, overlay=True, api_key='K87152346488957', language='eng'):
    payload = {'isOverlayRequired': overlay,
               'apikey': api_key,
               'language': language,
               }
    with open(filename, 'rb') as f:
        r = requests.post('https://api.ocr.space/parse/image',
                          files={'filename': f},
                          data=payload,
                          )
    return r.json()

# Replace 'K87152346488957' with your actual API key
api_key = 'K87152346488957'
# Replace 'VFS_App_Center.jpg' with the path to your image file
filename = 'not mention.png'

result = ocr_space_file(filename, api_key=api_key)
print(result)
# Process the result
if result['IsErroredOnProcessing']:
    print("Error occurred during processing.")
else:
    parsed_results = result['ParsedResults']
    for parsed_result in parsed_results:
        text = parsed_result['ParsedText']
        print("Extracted Text:")
        print(text)
# Out:
# {'ParsedResults': [{'TextOverlay': {'Lines': [{'LineText': 'Proof and Source of Funds Letter', 'Words': [{'WordText': 'Proof', 'Left': 257.0, 'Top': 127.0, 'Height': 24.0, 'Width': 77.0}, {'WordText': 'and', 'Left': 343.0, 'Top': 127.0, 'Height': 24.0, 'Width': 51.0}, {'WordText': 'Source', 'Left': 405.0, 'Top': 129.0, 'Height': 22.0, 'Width': 95.0}, {'WordText': 'of', 'Left': 510.0, 'Top': 127.0, 'Height': 24.0, 'Width': 29.0}, {'WordText': 'Funds', 'Left': 549.0, 'Top': 127.0, 'Height': 24.0, 'Width': 83.0}, {'WordText': 'Letter', 'Left': 642.0, 'Top': 129.0, 'Height': 22.0, 'Width': 82.0}], 'MaxHeight': 24.0, 'MinTop': 127.0}, {'LineText': 'Dear Madam/Sir,', 'Words': [{'WordText': 'Dear', 'Left': 99.0, 'Top': 183.0, 'Height': 12.0, 'Width': 36.0}, {'WordText': 'Madam/Sir,', 'Left': 141.0, 'Top': 181.0, 'Height': 17.0, 'Width': 88.0}], 'MaxHeight': 17.0, 'MinTop': 181.0}, {'LineText': 'This letter is the proof and source of funds letter. I hope I will make clear of all the transactions', 'Words': [{'WordText': 'This', 'Left': 98.0, 'Top': 232.0, 'Height': 13.0, 'Width': 31.0}, {'WordText': 'letter', 'Left': 135.0, 'Top': 232.0, 'Height': 13.0, 'Width': 40.0}, {'WordText': 'is', 'Left': 181.0, 'Top': 232.0, 'Height': 13.0, 'Width': 10.0}, {'WordText': 'the', 'Left': 196.0, 'Top': 232.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'proof', 'Left': 227.0, 'Top': 232.0, 'Height': 16.0, 'Width': 42.0}, {'WordText': 'and', 'Left': 273.0, 'Top': 232.0, 'Height': 13.0, 'Width': 28.0}, {'WordText': 'source', 'Left': 307.0, 'Top': 236.0, 'Height': 9.0, 'Width': 50.0}, {'WordText': 'of', 'Left': 363.0, 'Top': 232.0, 'Height': 13.0, 'Width': 16.0}, {'WordText': 'funds', 'Left': 382.0, 'Top': 232.0, 'Height': 13.0, 'Width': 43.0}, {'WordText': 'letter.', 'Left': 431.0, 'Top': 232.0, 'Height': 13.0, 'Width': 43.0}, {'WordText': 'I', 'Left': 480.0, 'Top': 233.0, 'Height': 12.0, 'Width': 3.0}, {'WordText': 'hope', 'Left': 489.0, 'Top': 232.0, 'Height': 16.0, 'Width': 38.0}, {'WordText': 'I', 'Left': 534.0, 'Top': 233.0, 'Height': 12.0, 'Width': 2.0}, {'WordText': 'will', 'Left': 542.0, 'Top': 232.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'make', 'Left': 574.0, 'Top': 232.0, 'Height': 13.0, 'Width': 40.0}, {'WordText': 'clear', 'Left': 619.0, 'Top': 232.0, 'Height': 13.0, 'Width': 37.0}, {'WordText': 'of', 'Left': 661.0, 'Top': 232.0, 'Height': 13.0, 'Width': 16.0}, {'WordText': 'all', 'Left': 682.0, 'Top': 232.0, 'Height': 13.0, 'Width': 16.0}, {'WordText': 'the', 'Left': 703.0, 'Top': 232.0, 'Height': 13.0, 'Width': 26.0}, {'WordText': 'transactions', 'Left': 733.0, 'Top': 232.0, 'Height': 13.0, 'Width': 95.0}], 'MaxHeight': 16.0, 'MinTop': 232.0}, {'LineText': 'happened in my account. Following are the transaction détails:', 'Words': [{'WordText': 'happened', 'Left': 99.0, 'Top': 257.0, 'Height': 16.0, 'Width': 76.0}, {'WordText': 'in', 'Left': 182.0, 'Top': 257.0, 'Height': 13.0, 'Width': 12.0}, {'WordText': 'my', 'Left': 200.0, 'Top': 261.0, 'Height': 12.0, 'Width': 23.0}, {'WordText': 'account.', 'Left': 228.0, 'Top': 259.0, 'Height': 11.0, 'Width': 64.0}, {'WordText': 'Following', 'Left': 299.0, 'Top': 257.0, 'Height': 16.0, 'Width': 73.0}, {'WordText': 'are', 'Left': 377.0, 'Top': 261.0, 'Height': 9.0, 'Width': 24.0}, {'WordText': 'the', 'Left': 406.0, 'Top': 257.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'transaction', 'Left': 436.0, 'Top': 257.0, 'Height': 13.0, 'Width': 86.0}, {'WordText': 'détails:', 'Left': 528.0, 'Top': 252.0, 'Height': 23.0, 'Width': 55.0}], 'MaxHeight': 23.0, 'MinTop': 252.0}, {'LineText': 'In July, a credit transaction happened which was my monthly salary of 700 SEK to my bank account', 'Words': [{'WordText': 'In', 'Left': 99.0, 'Top': 297.0, 'Height': 12.0, 'Width': 13.0}, {'WordText': 'July,', 'Left': 117.0, 'Top': 296.0, 'Height': 16.0, 'Width': 32.0}, {'WordText': 'a', 'Left': 155.0, 'Top': 300.0, 'Height': 9.0, 'Width': 7.0}, {'WordText': 'credit', 'Left': 168.0, 'Top': 296.0, 'Height': 13.0 ...
# Extracted Text:
# Proof and Source of Funds Letter
# Dear Madam/Sir,
# This letter is the proof and source of funds letter. I hope I will make clear of all the transactions
# happened in my account. Following are the transaction détails:
# In July, a credit transaction happened which was my monthly salary of 700 SEK to my bank account
# for which my friend sent it to my for birthday. Email transaction Document provided.
# And I don't have any other transactions shown worth mentioning in my bank statement. All
# transactions are referred from my side.
# Regards,
# Umar Farooq Khan

# %%
#!pip install openai
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key='sk-proj-oooooooooo')

# Define the conversation messages
from openai import OpenAI


response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": bankstatement_ocr +'''find transaction that are greater than 800 sek and cross check if there is a mention of that transaction in this text or not:
'''+ text+
'''In the reponse just write Positive if there is otherwise Negative'''
    }
  ],
  temperature=0,
  max_tokens=520,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
generated_response = response.choices[0].message.content

# Print the generated response
print("Generated Response:", generated_response)
# Out:
# Generated Response: Negative

# %% [markdown]
# # Now In case of all proofs of transactions given and supporting docs are attached

# %%
import requests

def ocr_space_file(filename, overlay=True, api_key='rrrr', language='eng'):
    payload = {'isOverlayRequired': overlay,
               'apikey': api_key,
               'language': language,
               }
    with open(filename, 'rb') as f:
        r = requests.post('https://api.ocr.space/parse/image',
                          files={'filename': f},
                          data=payload,
                          )
    return r.json()

# Replace 'K87152346488957' with your actual API key
api_key = 'rrrrr'
# Replace 'VFS_App_Center.jpg' with the path to your image file
filename = 'mention.png'

result = ocr_space_file(filename, api_key=api_key)
print(result)
# Process the result
if result['IsErroredOnProcessing']:
    print("Error occurred during processing.")
else:
    parsed_results = result['ParsedResults']
    for parsed_result in parsed_results:
        text = parsed_result['ParsedText']
        print("Extracted Text:")
        print(text)
# Out:
# {'ParsedResults': [{'TextOverlay': {'Lines': [{'LineText': 'Proof and Source of Funds Letter', 'Words': [{'WordText': 'Proof', 'Left': 271.0, 'Top': 130.0, 'Height': 24.0, 'Width': 77.0}, {'WordText': 'and', 'Left': 357.0, 'Top': 130.0, 'Height': 24.0, 'Width': 51.0}, {'WordText': 'Source', 'Left': 419.0, 'Top': 132.0, 'Height': 22.0, 'Width': 95.0}, {'WordText': 'of', 'Left': 524.0, 'Top': 130.0, 'Height': 24.0, 'Width': 29.0}, {'WordText': 'Funds', 'Left': 563.0, 'Top': 130.0, 'Height': 24.0, 'Width': 83.0}, {'WordText': 'Letter', 'Left': 656.0, 'Top': 132.0, 'Height': 22.0, 'Width': 82.0}], 'MaxHeight': 24.0, 'MinTop': 130.0}, {'LineText': 'Dear Madam/Sir,', 'Words': [{'WordText': 'Dear', 'Left': 113.0, 'Top': 186.0, 'Height': 12.0, 'Width': 36.0}, {'WordText': 'Madam/Sir,', 'Left': 155.0, 'Top': 184.0, 'Height': 17.0, 'Width': 88.0}], 'MaxHeight': 17.0, 'MinTop': 184.0}, {'LineText': 'This letter is the proof and source of funds letter. I hope I will make clear of all the transactions', 'Words': [{'WordText': 'This', 'Left': 112.0, 'Top': 235.0, 'Height': 13.0, 'Width': 31.0}, {'WordText': 'letter', 'Left': 149.0, 'Top': 235.0, 'Height': 13.0, 'Width': 40.0}, {'WordText': 'is', 'Left': 195.0, 'Top': 235.0, 'Height': 13.0, 'Width': 10.0}, {'WordText': 'the', 'Left': 210.0, 'Top': 235.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'proof', 'Left': 241.0, 'Top': 235.0, 'Height': 16.0, 'Width': 42.0}, {'WordText': 'and', 'Left': 287.0, 'Top': 235.0, 'Height': 13.0, 'Width': 28.0}, {'WordText': 'source', 'Left': 321.0, 'Top': 239.0, 'Height': 9.0, 'Width': 50.0}, {'WordText': 'of', 'Left': 377.0, 'Top': 235.0, 'Height': 13.0, 'Width': 15.0}, {'WordText': 'funds', 'Left': 396.0, 'Top': 235.0, 'Height': 13.0, 'Width': 43.0}, {'WordText': 'letter.', 'Left': 445.0, 'Top': 235.0, 'Height': 13.0, 'Width': 43.0}, {'WordText': 'I', 'Left': 494.0, 'Top': 236.0, 'Height': 12.0, 'Width': 3.0}, {'WordText': 'hope', 'Left': 503.0, 'Top': 235.0, 'Height': 16.0, 'Width': 38.0}, {'WordText': 'I', 'Left': 548.0, 'Top': 236.0, 'Height': 12.0, 'Width': 2.0}, {'WordText': 'will', 'Left': 556.0, 'Top': 235.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'make', 'Left': 588.0, 'Top': 235.0, 'Height': 13.0, 'Width': 40.0}, {'WordText': 'clear', 'Left': 633.0, 'Top': 235.0, 'Height': 13.0, 'Width': 37.0}, {'WordText': 'of', 'Left': 675.0, 'Top': 235.0, 'Height': 13.0, 'Width': 16.0}, {'WordText': 'all', 'Left': 696.0, 'Top': 235.0, 'Height': 13.0, 'Width': 16.0}, {'WordText': 'the', 'Left': 717.0, 'Top': 235.0, 'Height': 13.0, 'Width': 26.0}, {'WordText': 'transactions', 'Left': 747.0, 'Top': 235.0, 'Height': 13.0, 'Width': 95.0}], 'MaxHeight': 16.0, 'MinTop': 235.0}, {'LineText': 'happened in my account. Following are the transaction details:', 'Words': [{'WordText': 'happened', 'Left': 113.0, 'Top': 260.0, 'Height': 16.0, 'Width': 76.0}, {'WordText': 'in', 'Left': 196.0, 'Top': 260.0, 'Height': 13.0, 'Width': 12.0}, {'WordText': 'my', 'Left': 214.0, 'Top': 264.0, 'Height': 12.0, 'Width': 23.0}, {'WordText': 'account.', 'Left': 242.0, 'Top': 262.0, 'Height': 11.0, 'Width': 64.0}, {'WordText': 'Following', 'Left': 313.0, 'Top': 260.0, 'Height': 16.0, 'Width': 73.0}, {'WordText': 'are', 'Left': 391.0, 'Top': 264.0, 'Height': 9.0, 'Width': 24.0}, {'WordText': 'the', 'Left': 420.0, 'Top': 260.0, 'Height': 13.0, 'Width': 25.0}, {'WordText': 'transaction', 'Left': 450.0, 'Top': 260.0, 'Height': 13.0, 'Width': 86.0}, {'WordText': 'details:', 'Left': 542.0, 'Top': 260.0, 'Height': 13.0, 'Width': 55.0}], 'MaxHeight': 16.0, 'MinTop': 260.0}, {'LineText': 'In July, a credit transaction happened which was my monthly salary of 34 678.80 SEK to my bank', 'Words': [{'WordText': 'In', 'Left': 113.0, 'Top': 300.0, 'Height': 12.0, 'Width': 13.0}, {'WordText': 'July,', 'Left': 131.0, 'Top': 299.0, 'Height': 16.0, 'Width': 32.0}, {'WordText': 'a', 'Left': 169.0, 'Top': 303.0, 'Height': 9.0, 'Width': 7.0}, {'WordText': 'credit', 'Left': 182.0, 'Top': 299.0, 'Height': 13 ...
# Extracted Text:
# Proof and Source of Funds Letter
# Dear Madam/Sir,
# This letter is the proof and source of funds letter. I hope I will make clear of all the transactions
# happened in my account. Following are the transaction details:
# In July, a credit transaction happened which was my monthly salary of 34 678.80 SEK to my bank
# account for which I have attached the salary slip for that month.
# And I don't have any other transactions shown worth mentioning in my bank statement. All
# transactions are referred from my side.
# Regards,
# Umar Farooq Khan

# %%
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key='sk-proj-rrrrrrr')

# Define the conversation messages
from openai import OpenAI


response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": bankstatement_ocr +'''find transaction that are greater than 800 sek and cross check if there is a mention of that transaction in this text or not:
'''+ text+
'''In the reponse just write Positive if there is otherwise Negative'''
    }
  ],
  temperature=0,
  max_tokens=520,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
generated_response = response.choices[0].message.content

# Print the generated response
print("Generated Response:", generated_response)
# Out:
# Generated Response: Positive
